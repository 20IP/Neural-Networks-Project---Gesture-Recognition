# %% [markdown]
# # Gesture Recognition
# In this group project, you are going to build a 3D Conv model that will be able to predict the 5 gestures correctly. Please import the following libraries to get started.

# %% [markdown]
# ## Import the Libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# !unzip /content/drive/MyDrive/Gesture_Recognition_Project/Project_data.zip
# drive.flush_and_unmount()
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import os
import datetime
import os
import random as rn
import matplotlib.pyplot as plt
import tensorflow as tf
import cv2

from imageio import imread
from skimage.transform import resize

from keras import backend as K
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, LSTM, Bidirectional, Flatten,RepeatVector, TimeDistributed, Flatten, BatchNormalization, Activation, Dropout
from keras.layers.convolutional import Conv3D, MaxPooling3D, Conv2D, MaxPooling2D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras import optimizers
from keras.applications.vgg16 import VGG16

tf.__version__
# Out:
# '2.9.2'

# %% [markdown]
# ## Import the Dataset

# %% [markdown]
# Mount your Google Drive and unzip the dataset into the workspace.
# The dataset must be in following folder on your Google Drive:
# ```
# Gesture_Recognition_Project/Project_data.zip
# ```

# %% [markdown]
# Set the random seed so that the results don't vary drastically.

# %%
np.random.seed(30)
rn.seed(30)
tf.keras.utils.set_random_seed(30)

# %% [markdown]
# Set the folder names for training and validation.

# %%
train_doc = np.random.permutation(open('/content/Project_data/train.csv').readlines())
val_doc = np.random.permutation(open('/content/Project_data/val.csv').readlines())

batch_size = 16
num_epochs = 20
img_idx = [*range(1, 30, 2)]
image_width = 120
image_height = 120
target_size = (image_width, image_height, 3)

# %% [markdown]
# - Create default "steps per epochs" and "validation steps"

# %%
curr_dt_time = datetime.datetime.now()
train_path = 'Project_data/train'
val_path = 'Project_data/val'
num_train_sequences = len(train_doc)
print('# Training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# Validation sequences =', num_val_sequences)
print ('# epochs =', num_epochs)

def get_step(num_train_sequences, num_val_sequences, batch_size):
  if (num_train_sequences%batch_size) == 0:
      steps_per_epoch = int(num_train_sequences/batch_size)
  else:
      steps_per_epoch = (num_train_sequences//batch_size) + 1

  if (num_val_sequences%batch_size) == 0:
      validation_steps = int(num_val_sequences/batch_size)
  else:
      validation_steps = (num_val_sequences//batch_size) + 1
  return steps_per_epoch, validation_steps

steps_per_epoch, validation_steps = get_step(num_train_sequences, num_val_sequences, batch_size)
    
print('# Step per Epochs = ',steps_per_epoch)
print('# Validation steps = ', validation_steps)
# Out:
# # Training sequences = 663
# # Validation sequences = 100
# # epochs = 20
# # Step per Epochs =  42
# # Validation steps =  7

# %% [markdown]
# ## Generator
# Using all the imgages in the sequences gives the best results.  But one can skip over every second image in the sequece to reduce the memory footprint by setting:
#
# ```
# img_idx = [*range(1, 30, 2)]
# ```
#
# The image dimensions used are 120x120 pixels.  Images that are 160x120 are cropped to 120x120, and images that are 360x360 are resized using a Lanczos filter.  Resizing images by an integer factor minimizes the introduction of resizing artifacts.

# %%
img_idx = list(range(0,30))
x=len(img_idx)

def feature_extraction(target_size):
    extract_pretrained = tf.keras.applications.VGG16(weights='imagenet',
                                                    include_top=False,
                                                    pooling="avg")
    preprocess_input = tf.keras.applications.vgg16.preprocess_input

    inputs = tf.keras.Input(target_size)
    preprocessed = preprocess_input(inputs)

    outputs = extract_pretrained(preprocessed)
    return tf.keras.Model(inputs, outputs, name="feature_extractor")
getFeature = feature_extraction(target_size)

def generator_feature(source_path, folder_list, batch_size, target_size):
    '''
        The function yield each of data Feature Extractor with shape [batch_size, sequence_len, feature_shape]
        source_path: str
        folder_list: list, total folders containing videos
        batch_size: int
        target_size: tuple(height, width, channel)
    '''
    print( ' Source path = ', source_path, '; Batch size =', batch_size)
    y, z, _ = target_size
    while True:
        shuf = np.random.permutation(folder_list)
        num_batches = len(folder_list)//batch_size
        path_inter = 0
        for batch in range(num_batches):
            batch_data = np.zeros((batch_size,x,512))
            batch_labels = np.zeros((batch_size,5))
            for folder in range(batch_size):
                imgs = os.listdir(source_path+'/'+ shuf[folder + (batch*batch_size)].split(';')[0])
                for idx,item in enumerate(img_idx):
                    image = cv2.imread(source_path+'/'+ shuf[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item])
                    image = cv2.resize(image, (y,z), interpolation=cv2.INTER_LANCZOS4)
                    image = np.expand_dims(image, axis=0)
                    batch_data[folder,idx,:] = getFeature(image)
                    
                batch_labels[folder, int(shuf[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            path_inter = batch
            yield batch_data, batch_labels
            
        folders_not_process = len(folder_list)-num_batches*batch_size
        if folders_not_process !=0:
            path_inter+=1
            batch_data = np.zeros((folders_not_process,x,512))
            batch_labels = np.zeros((folders_not_process,5))

            for folder in range(folders_not_process):
                imgs = os.listdir(source_path+'/'+ shuf[folder + (path_inter*batch_size)].split(';')[0])
                for idx,item in enumerate(img_idx):
                    image = cv2.imread(source_path+'/'+ shuf[folder + (path_inter*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    image = cv2.resize(image, (y,z), interpolation=cv2.INTER_LANCZOS4)
                    image = np.expand_dims(image, axis=0)
                    batch_data[folder,idx,:] = getFeature(image)
                batch_labels[folder, int(shuf[folder + (path_inter*batch_size)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels
            
def generator(source_path, folder_list, batch_size, target_size, scale_type=0):
    '''
        The function yield each of data with shape [batch_size, sequence_len, shape_x, shape_y, channel]
        source_path: str
        folder_list: list, total folders containing videos
        batch_size: int
        target_size: tuple(height, width, channel)
        scale_type: --->    '0':  divide pixel value by 255 (default)
                            '1':  scale zero center (img-127)/127.
                            '2':  scale distribution of quantitative data ( image -= img_mean
                                                                            image /= img_std)
                           ------------------ ********** -------------------
        
    '''
    print( ' Source path = ', source_path, '; Batch size =', batch_size)
    y, z, _ = target_size
    while True:
        shuf = np.random.permutation(folder_list)
        num_batches = len(folder_list)//batch_size
        path_inter = 0
        for batch in range(num_batches):
            batch_data = np.zeros((batch_size,x,y,z,3))
            batch_labels = np.zeros((batch_size,5))
            for folder in range(batch_size):
                imgs = os.listdir(source_path+'/'+ shuf[folder + (batch*batch_size)].split(';')[0])
                for idx,item in enumerate(img_idx):
                    image = cv2.imread(source_path+'/'+ shuf[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    
                    if image.shape[0] == 120 and image.shape[1] == 160:
                        image = image[0:120, 20:140]
                    else:
                        image = cv2.resize(image, (y,z), interpolation=cv2.INTER_LANCZOS4)
                    
                    if scale_type == 1:
                        batch_data[folder,idx,:,:,:] = (image - 127)/127.
                    elif scale_type == 2:
                        img_mean = [0.485, 0.456, 0.406]
                        img_std = [0.229, 0.224, 0.225]
                        image = image / 255
                        image -= img_mean
                        image /= img_std
                        batch_data[folder,idx,:,:,:] = image
                    else:
                        batch_data[folder,idx,:,:,:] = image/255.
                    
                batch_labels[folder, int(shuf[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            path_inter = batch
            yield batch_data, batch_labels        
        
        folders_not_process = len(folder_list)-num_batches*batch_size # vidu bang 3
        if folders_not_process !=0:
            path_inter+=1
            batch_data = np.zeros((folders_not_process,x,y,z,3))
            batch_labels = np.zeros((folders_not_process,5))

            for folder in range(folders_not_process):
                imgs = os.listdir(source_path+'/'+ shuf[folder + (path_inter*batch_size)].split(';')[0])
                for idx,item in enumerate(img_idx):
                    image = cv2.imread(source_path+'/'+ shuf[folder + (path_inter*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    
                    if image.shape[0] == 120 and image.shape[1] == 160:
                        image = image[0:120, 20:140]
                    else:
                        image = cv2.resize(image, (y,z), interpolation=cv2.INTER_LANCZOS4)
                    
                    if scale_type == 1:
                        batch_data[folder,idx,:,:,:] = (image - 127)/127.
                    elif scale_type == 2:
                        img_mean = [0.485, 0.456, 0.406]
                        img_std = [0.229, 0.224, 0.225]
                        image /= image
                        image -= img_mean
                        image /= img_std
                        batch_data[folder,idx,:,:,:] = image
                    else:
                        batch_data[folder,idx,:,:,:] = image/255.
                    
                batch_labels[folder, int(shuf[folder + (path_inter*batch_size)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels

# %% [markdown]
# ## Model Definitions

# %%
class Gesture_Module:
    def __init__(self, input_shape, no_class):
        self.input_shape = input_shape
        self.no_class = no_class
        
    def cnn3d_lstm(self):
        model = Sequential(name='cnn3D_lstm')

        model.add(Conv3D(16, (3,3,3), input_shape=self.input_shape))
        model.add(MaxPooling3D((2,2,2)))
        
        model.add(Conv3D(32, (3,3,3), activation='relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D((2,2,2)))
        
        
        model.add(Conv3D(32, (3,3,3), activation='relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D((2,2,2)))
        model.add(Flatten())

        model.add(RepeatVector(len(img_idx)))
        model.add(LSTM(128, return_sequences=False))
        model.add(Dropout(0.2))
        model.add(Dense(32, activation='relu'))
        model.add(Dense(self.no_class, activation='softmax'))
        return model

    def cnn_lstm(self):
        model = Sequential(name='cnn_lstm')
        model.add(TimeDistributed(Conv2D(8,(3,3),strides=(2,2)), input_shape=self.input_shape))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(Activation('relu')))
        model.add(TimeDistributed(MaxPooling2D((2,2), strides=(2,2))))

        model.add(TimeDistributed(Conv2D(8,(3,3))))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(Activation('relu')))
        model.add(TimeDistributed(MaxPooling2D((2,2), strides=(2,2))))

        model.add(TimeDistributed(Conv2D(32,(3,3))))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(Activation('relu')))
        model.add(TimeDistributed(MaxPooling2D((2,2), strides=(2,2))))

        model.add(TimeDistributed(Conv2D(32,(3,3))))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(Activation('relu')))
        model.add(TimeDistributed(MaxPooling2D((2,2), strides=(2,2))))

        model.add(TimeDistributed(Flatten()))

        model.add(Dense(64, activation='relu'))
        model.add(Dropout(0.25))
        model.add(LSTM(64, return_sequences=False))
        model.add(Dense(self.no_class, activation='softmax'))
        return model

    def cnn_gru(self):
        model = Sequential(name='cnn_gru')
        model.add(TimeDistributed(Conv2D(8,(3,3),strides=(2,2)), input_shape=self.input_shape))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(Activation('relu')))
        model.add(TimeDistributed(MaxPooling2D((2,2), strides=(2,2))))

        model.add(TimeDistributed(Conv2D(8,(3,3))))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(Activation('relu')))
        model.add(TimeDistributed(MaxPooling2D((2,2), strides=(2,2))))

        model.add(TimeDistributed(Conv2D(32,(3,3))))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(Activation('relu')))
        model.add(TimeDistributed(MaxPooling2D((2,2), strides=(2,2))))

        model.add(TimeDistributed(Conv2D(32,(3,3))))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(Activation('relu')))
        model.add(TimeDistributed(MaxPooling2D((2,2), strides=(2,2))))

        model.add(TimeDistributed(Flatten()))
        model.add(GRU(64, return_sequences=True))
        model.add(Dense(64, activation='relu'))
        model.add(Dropout(0.25))
        model.add(Dense(64, activation='relu'))
        model.add(GRU(32, return_sequences=False))
        model.add(Dense(self.no_class, activation='softmax'))
        return model
    
    def feature_lstm_model(self):
        frame_features_input = tf.keras.Input((30, 512))

        x = GRU(32, return_sequences=False)(frame_features_input)
        x = BatchNormalization(x)
        x = Dropout(0.3)(x)
        x = Dense(32)(x)
        x = BatchNormalization()(x)
        x = tf.keras.activations.relu(x)
        output = Dense(self.no_class, activation='relu')(x)
        pretrained_vgg16 = tf.keras.Model([frame_features_input], output, name='extract_feature_vgg16')
        return pretrained_vgg16
    
    def pretrained_vgg_gru(self):
        vgg_structure = VGG16(include_top=False,
                              weights='imagenet',
                              input_shape=(self.input_shape[1:]))
        
        vgg_output = vgg_structure.layers[-1].output
        vgg_output = Flatten()(vgg_output)
        vgg_backbone = Model(vgg_structure.input, outputs=vgg_output)
        
        for layer in vgg_backbone.layers:
            layer.trainable = False
        
        pretrained_vgg_gru = Sequential(name='pretrained_vgg16_gru')
        pretrained_vgg_gru.add(TimeDistributed(vgg_backbone, input_shape=self.input_shape))
        pretrained_vgg_gru.add(TimeDistributed(Flatten()))
        pretrained_vgg_gru.add(GRU(256, activation='relu', return_sequences=False))
        pretrained_vgg_gru.add(BatchNormalization())
        pretrained_vgg_gru.add(Dropout(0.25))
        pretrained_vgg_gru.add(Dense(32, activation='relu'))
        pretrained_vgg_gru.add(BatchNormalization())
        pretrained_vgg_gru.add(Dropout(0.25))
        pretrained_vgg_gru.add(Dense(self.no_class, activation='softmax'))
        return pretrained_vgg_gru

# %% [markdown]
# Configure and instantiate the model class

# %% [markdown]
# ## Plotting Functions

# %%
# Function to plot the model accuracy
def plot_accuracy(history):
    plt.figure(figsize=(8,5))
    plt.plot(history.history['categorical_accuracy'])
    plt.plot(history.history['val_categorical_accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

# Function to plot the model loss
def plot_loss(history):
    plt.figure(figsize=(8,5))
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
# model storage path constructor
def save_model_path(model_name):
    model_name = 'output/'+model_name + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    if not os.path.exists(model_name):
        os.makedirs(model_name)
    filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'
    return filepath

# %%
# Number of classification classes
no_class = 5

# Input shape
input_shape = (len(img_idx), image_height, image_width, 3)

# Instantiate the model class
GestureNet = Gesture_Module(input_shape, no_class)

# %% [markdown]
# ## CNN3d + LSTM Model

# %%
# set the batch_size
batch_size = 24 
# Re calculate steps_per_epoch, validation_steps
steps_per_epoch, validation_steps = get_step(num_train_sequences, num_val_sequences, batch_size)

model_cnn3d_lstm  = GestureNet.cnn3d_lstm()

train_generator = generator(train_path, train_doc, batch_size, target_size, scale_type=1)
val_generator = generator(val_path, val_doc, batch_size, target_size, scale_type=1)

filepath = save_model_path(model_cnn3d_lstm.name)

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)
LR = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',
                                         factor=0.2,
                                         patience=5,
                                         mode='auto',
                                         min_lr=1e-5)
callbacks_list = [checkpoint, LR]
opt = tf.keras.optimizers.Adam(learning_rate=1e-3,)
model_cnn3d_lstm.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model_cnn3d_lstm.summary())
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Model: "cnn3D_lstm"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv3d (Conv3D)             (None, 28, 118, 118, 16)  1312
#
#  max_pooling3d (MaxPooling3D  (None, 14, 59, 59, 16)   0
#  )
#
#  conv3d_1 (Conv3D)           (None, 12, 57, 57, 32)    13856
#
#  batch_normalization (BatchN  (None, 12, 57, 57, 32)   128
#  ormalization)
#
#  max_pooling3d_1 (MaxPooling  (None, 6, 28, 28, 32)    0
#  3D)
#
#  conv3d_2 (Conv3D)           (None, 4, 26, 26, 32)     27680
#
#  batch_normalization_1 (Batc  (None, 4, 26, 26, 32)    128
#  hNormalization)
#
#  max_pooling3d_2 (MaxPooling  (None, 2, 13, 13, 32)    0
#  3D)
#
#  flatten (Flatten)           (None, 10816)             0
#
#  repeat_vector (RepeatVector  (None, 30, 10816)        0
#  )
#
# ...

# %%
# Plot a diagram of the model
tf.keras.utils.plot_model(model_cnn3d_lstm, "cnn3d_lstm.png", show_shapes=True)

# %%
#Train with Epochs=20
num_epochs=20
model_cnn3d_lstm.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   """
#  Source path =  Project_data/train ; Batch size = 24
# Epoch 1/20
# 28/28 [==============================] - ETA: 0s - loss: 1.4012 - categorical_accuracy: 0.3891 Source path =  Project_data/val ; Batch size = 24
#
# Epoch 1: saving model to output/cnn3D_lstm_2022-11-1410_17_04.965412/model-00001-1.40117-0.38914-2.19847-0.27000.h5
# 28/28 [==============================] - 62s 2s/step - loss: 1.4012 - categorical_accuracy: 0.3891 - val_loss: 2.1985 - val_categorical_accuracy: 0.2700 - lr: 0.0010
# Epoch 2/20
# 28/28 [==============================] - ETA: 0s - loss: 1.2101 - categorical_accuracy: 0.5083
# Epoch 2: saving model to output/cnn3D_lstm_2022-11-1410_17_04.965412/model-00002-1.21008-0.50830-1.90212-0.24000.h5
# ...

# %%
# Plot the model accuracy
plot_accuracy(model_cnn3d_lstm.history)

# %%
# Plot the model loss
plot_loss(model_cnn3d_lstm.history)

# %% [markdown]
# ## CNN + LSTM Model

# %%
model_cnn_lstm = GestureNet.cnn_lstm()

train_generator = generator(train_path, train_doc, batch_size, target_size, scale_type=0)
val_generator = generator(val_path, val_doc, batch_size, target_size, scale_type=0)

filepath = save_model_path(model_cnn_lstm.name)

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)
LR = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',
                                         factor=0.2,
                                         patience=5,
                                         mode='auto',
                                         min_lr=1e-5)
callbacks_list = [checkpoint, LR]
opt = tf.keras.optimizers.Adam(learning_rate=1e-3,)
model_cnn_lstm.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model_cnn_lstm.summary())
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Model: "cnn_lstm"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  time_distributed (TimeDistr  (None, 30, 59, 59, 8)    224
#  ibuted)
#
#  time_distributed_1 (TimeDis  (None, 30, 59, 59, 8)    32
#  tributed)
#
#  time_distributed_2 (TimeDis  (None, 30, 59, 59, 8)    0
#  tributed)
#
#  time_distributed_3 (TimeDis  (None, 30, 29, 29, 8)    0
#  tributed)
#
#  time_distributed_4 (TimeDis  (None, 30, 27, 27, 8)    584
#  tributed)
#
#  time_distributed_5 (TimeDis  (None, 30, 27, 27, 8)    32
#  tributed)
#
#  time_distributed_6 (TimeDis  (None, 30, 27, 27, 8)    0
#  tributed)
#
#  time_distributed_7 (TimeDis  (None, 30, 13, 13, 8)    0
#  tributed)
#
#  time_distributed_8 (TimeDis  (None, 30, 11, 11, 32)   2336
#  tributed)
#
# ...

# %%
# Plot a diagram of the model
tf.keras.utils.plot_model(model_cnn_lstm, "model_cnn_lstm.png", show_shapes=True)

# %%
# Train the model for 20 epochs
num_epochs=20
steps_per_epoch, validation_steps = get_step(num_train_sequences, num_val_sequences, batch_size)

model_cnn_lstm.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                            callbacks=callbacks_list, validation_data=val_generator, 
                            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   import sys
#  Source path =  Project_data/train ; Batch size = 24
# Epoch 1/20
# 28/28 [==============================] - ETA: 0s - loss: 1.4979 - categorical_accuracy: 0.3484 Source path =  Project_data/val ; Batch size = 24
#
# Epoch 1: saving model to output/cnn_lstm_2022-11-1410_17_04.965412/model-00001-1.49792-0.34842-1.60287-0.23000.h5
# 28/28 [==============================] - 54s 2s/step - loss: 1.4979 - categorical_accuracy: 0.3484 - val_loss: 1.6029 - val_categorical_accuracy: 0.2300 - lr: 0.0010
# Epoch 2/20
# 28/28 [==============================] - ETA: 0s - loss: 1.1909 - categorical_accuracy: 0.5264
# Epoch 2: saving model to output/cnn_lstm_2022-11-1410_17_04.965412/model-00002-1.19091-0.52640-1.51822-0.33000.h5
# ...

# %%
# Plot the model accuracy
plot_accuracy(model_cnn_lstm.history)

# %%
# Plot the model loss
plot_loss(model_cnn_lstm.history)

# %% [markdown]
# ## CNN + GRU Model

# %%
model_cnn_gru = GestureNet.cnn_gru()

train_generator = generator(train_path, train_doc, batch_size, target_size, scale_type=1)
val_generator = generator(val_path, val_doc, batch_size, target_size, scale_type=1)

filepath = save_model_path(model_cnn_gru.name)

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)
LR = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',
                                         factor=0.2,
                                         patience=5,
                                         mode='auto',
                                         min_lr=1e-5)
callbacks_list = [checkpoint, LR]
opt = tf.keras.optimizers.Adam(learning_rate=1e-3,)
model_cnn_gru.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model_cnn_gru.summary())
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Model: "cnn_gru"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  time_distributed_17 (TimeDi  (None, 30, 59, 59, 8)    224
#  stributed)
#
#  time_distributed_18 (TimeDi  (None, 30, 59, 59, 8)    32
#  stributed)
#
#  time_distributed_19 (TimeDi  (None, 30, 59, 59, 8)    0
#  stributed)
#
#  time_distributed_20 (TimeDi  (None, 30, 29, 29, 8)    0
#  stributed)
#
#  time_distributed_21 (TimeDi  (None, 30, 27, 27, 8)    584
#  stributed)
#
#  time_distributed_22 (TimeDi  (None, 30, 27, 27, 8)    32
#  stributed)
#
#  time_distributed_23 (TimeDi  (None, 30, 27, 27, 8)    0
#  stributed)
#
#  time_distributed_24 (TimeDi  (None, 30, 13, 13, 8)    0
#  stributed)
#
#  time_distributed_25 (TimeDi  (None, 30, 11, 11, 32)   2336
#  stributed)
#
# ...

# %%
# Plot a diagram of the model
tf.keras.utils.plot_model(model_cnn_gru, "model_cnn_gru.png", show_shapes=True)

# %%
# Train the model for 20 epochs
model_cnn_gru.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                            callbacks=callbacks_list, validation_data=val_generator, 
                            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   after removing the cwd from sys.path.
#  Source path =  Project_data/train ; Batch size = 24
# Epoch 1/20
# 28/28 [==============================] - ETA: 0s - loss: 1.4771 - categorical_accuracy: 0.3529 Source path =  Project_data/val ; Batch size = 24
#
# Epoch 1: saving model to output/cnn_gru_2022-11-1410_17_04.965412/model-00001-1.47710-0.35294-1.46465-0.46000.h5
# 28/28 [==============================] - 58s 2s/step - loss: 1.4771 - categorical_accuracy: 0.3529 - val_loss: 1.4646 - val_categorical_accuracy: 0.4600 - lr: 0.0010
# Epoch 2/20
# 28/28 [==============================] - ETA: 0s - loss: 1.2048 - categorical_accuracy: 0.4887
# Epoch 2: saving model to output/cnn_gru_2022-11-1410_17_04.965412/model-00002-1.20477-0.48869-2.04772-0.20000.h5
# ...

# %%
# Plot the model accuracy
plot_accuracy(model_cnn_gru.history)

# %%
# Plot the model loss
plot_loss(model_cnn_gru.history)

# %% [markdown]
# ## Feature Extraction with VGG16 + GRU

# %%
feature_lstm_model = GestureNet.feature_lstm_model()
batch_size=16
steps_per_epoch, validation_steps = get_step(num_train_sequences, num_val_sequences, batch_size)
train_generator = generator_feature(train_path, train_doc, batch_size, target_size)
val_generator = generator_feature(val_path, val_doc, batch_size, target_size)

filepath = save_model_path(feature_lstm_model.name)

checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)
LR = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',
                                         factor=0.2,
                                         patience=5,
                                         mode='auto',
                                         min_lr=1e-5)
callbacks_list = [checkpoint, LR]
opt = tf.keras.optimizers.Adam(learning_rate=1e-4,)
feature_lstm_model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['categorical_accuracy'])

print(feature_lstm_model.summary())
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Model: "extract_feature_vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_4 (InputLayer)        [(None, 30, 512)]         0
#
#  lstm_3 (LSTM)               (None, 32)                69760
#
#  batch_normalization_12 (Bat  (None, 32)               128
#  chNormalization)
#
#  dropout_4 (Dropout)         (None, 32)                0
#
#  dense_8 (Dense)             (None, 32)                1056
#
#  batch_normalization_13 (Bat  (None, 32)               128
#  chNormalization)
#
#  tf.nn.relu_1 (TFOpLambda)   (None, 32)                0
#
#  custom_gru_01 (Dense)       (None, 5)                 165
#
# ...
# Total params: 71,237
# Trainable params: 71,109
# Non-trainable params: 128
# _________________________________________________________________
# None

# %%
# Plot a diagram of the model
tf.keras.utils.plot_model(feature_lstm_model, "feature_lstm_model.png", show_shapes=True)

# %%
# Run with epochs = 20
num_epochs=20
history = feature_lstm_model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   """
#  Source path =  Project_data/train ; Batch size = 16
# Epoch 1/20
# 42/42 [==============================] - ETA: 0s - loss: 1.8511 - categorical_accuracy: 0.2443 Source path =  Project_data/val ; Batch size = 16
#
# Epoch 1: saving model to output/extract_feature_vgg16_2022-11-1410_17_04.965412/model-00001-1.85111-0.24434-1.67607-0.24000.h5
# 42/42 [==============================] - 311s 8s/step - loss: 1.8511 - categorical_accuracy: 0.2443 - val_loss: 1.6761 - val_categorical_accuracy: 0.2400 - lr: 1.0000e-04
# Epoch 2/20
# 42/42 [==============================] - ETA: 0s - loss: 1.7564 - categorical_accuracy: 0.2534
# Epoch 2: saving model to output/extract_feature_vgg16_2022-11-1410_17_04.965412/model-00002-1.75642-0.25339-1.68190-0.23000.h5
# ...

# %%
plot_accuracy(feature_lstm_model.history)

# %%
plot_loss(feature_lstm_model.history)

# %% [markdown]
# ## Pretrained VGG16 + GRU Model

# %%
# Set the batch size
batch_size = 6
#Re calculation steps_per_epoch, validation_steps
steps_per_epoch, validation_steps = get_step(num_train_sequences, num_val_sequences, batch_size)

# Configurate the generator
train_generator = generator(train_path, train_doc, batch_size, target_size, scale_type=1)
val_generator = generator(val_path, val_doc, batch_size, target_size, scale_type=1)

pretrained_vgg_gru = GestureNet.pretrained_vgg_gru()

filepath = save_model_path(pretrained_vgg_gru.name)

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)
LR = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',
                                         factor=0.2,
                                         patience=5,
                                         mode='auto',
                                         min_lr=1e-5)
callbacks_list = [checkpoint, LR]
opt = tf.keras.optimizers.Adam(learning_rate=1e-3)
pretrained_vgg_gru.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['categorical_accuracy'])

print(pretrained_vgg_gru.summary())
# Out:
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Model: "pretrained_vgg16_gru"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  time_distributed_34 (TimeDi  (None, 30, 4608)         14714688
#  stributed)
#
#  time_distributed_35 (TimeDi  (None, 30, 4608)         0
#  stributed)
#
#  gru_2 (GRU)                 (None, 256)               3737088
#
#  batch_normalization_14 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_5 (Dropout)         (None, 256)               0
#
#  dense_9 (Dense)             (None, 32)                8224
#
#  batch_normalization_15 (Bat  (None, 32)               128
#  chNormalization)
#
# ...

# %%
# Plot a diagram of the model
tf.keras.utils.plot_model(pretrained_vgg_gru, "vgg_lstm.png", show_shapes=True)

# %%
# Train the model for 50 epochs
pretrained_vgg_gru.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=50, verbose=1, 
                                  callbacks=callbacks_list, validation_data=val_generator, 
                                  validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   after removing the cwd from sys.path.
#  Source path =  Project_data/train ; Batch size = 6
# Epoch 1/50
# 111/111 [==============================] - ETA: 0s - loss: 1.5404 - categorical_accuracy: 0.4329 Source path =  Project_data/val ; Batch size = 6
#
# Epoch 1: saving model to output/pretrained_vgg16_gru_2022-11-1410_17_04.965412/model-00001-1.54042-0.43288-2.22129-0.35000.h5
# 111/111 [==============================] - 72s 594ms/step - loss: 1.5404 - categorical_accuracy: 0.4329 - val_loss: 2.2213 - val_categorical_accuracy: 0.3500 - lr: 0.0010
# Epoch 2/50
# 111/111 [==============================] - ETA: 0s - loss: 0.8858 - categorical_accuracy: 0.6621
# ...

# %%
# Plot the model accuracy
plot_accuracy(pretrained_vgg_gru.history)

# %%
# Plot the model loss
plot_loss(pretrained_vgg_gru.history)
